# %%
import numpy as np #numeric library
import matplotlib.pyplot as plt # main plot
import seaborn as sns #high end plotting function
import pandas as pd # main library for analysis
import os #files and folder
from mpl_toolkits.mplot3d import Axes3D #3d plo

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '730_pandas.ipynb',
#  'all_t_p_func.txt',
#  'b.csv',
#  'Conditions.ipynb',
#  'data analysis',
#  'data_analysis.ipynb',
#  'good_books.ipynb',
#  'googleplaystore.csv',
#  'hw_learn.ipynb',
#  'images',
#  'image_manipulator.ipynb',
#  'IO opertions.ipynb',
#  'LIst.ipynb',
#  'movies.csv',
#  'numpy.ipynb',
#  'nyc-jobs.csv',
#  'Popular_Books',
#  'Popular_Books.csv',
#  'predefined_functions_and_library.ipynb',
#  'py_learn',
#  'py_learn - Shortcut.lnk',
#  'rain.txt',
#  'rainy.txt',
#  'scrappy.ipynb',
#  'set.ipynb',
#  'Skool_r.ipynb',
#  'Skool_Rankings.csv',
#  'Skool_Rankings_Imp.csv',
#  'Skool_Rankings_Improved.csv',
#  'Strings.ipynb',
#  'tuple.ipynb',
#  'Untitled.ipynb',
#  'year_vs_values.png',
#  'year_vs_values1.png']

# %%
app=pd.read_csv('googleplaystore.csv')

# %%
app.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
for item in app:
    print(item)
# Out:
# App
# Category
# Rating
# Reviews
# Size
# Installs
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
app[['Rating']].head().plot(title='rating of top 5 Apps',kind='bar')
plt.xlabel('App')
plt.ylabel('rating')

plt.show()

# %% [markdown]
# Rating is only directly plotable coloumn in this csv file ,
# this rating of top 5 App

# %%
a=app.Category.value_counts()
plt.figure(figsize=(20,10))
a.plot(kind='barh')

# %% [markdown]
# This graph shows classification on basis of category ,Family has most occurence in the csv file

# %%
a=app.Rating.value_counts()
plt.figure(figsize=(20,10))
a.plot(kind='bar',color='y',edgecolor='r')

# %% [markdown]
# This graph tells that 4.4 Rating is most common Rating give to the apps

# %%
a=app.Genres.value_counts()
plt.figure(figsize=(20,100))
a.plot(kind='barh',color='g')
plt.show()

# %% [markdown]
# Now This Horizontal Bar Graph Tells that most downloaded app is of Tools genre

# %%
app.Installs.value_counts().plot(kind='line')
plt.figure(figsize=(100,100))
plt.figure(facecolor='g')

# %% [markdown]
# This line graph shows that 1000000 is most common 'downloaded times' on playstore which means that a app has most probablity of being download this number of times

# %%
p=app.Size.value_counts()
p.plot(kind='line')
plt.xlabel('Sizes of apps')
plt.ylabel('Popularity of apps downloaded size wise')
# Out:
# Text(0, 0.5, 'Popularity of apps downloaded size wise')

# %% [markdown]
# Now this line graph tell that popularity of app generally decreases as it size decreases most of the time leaving exceptions

# %%
w=app.groupby(by='Genres').mean()
w
# Out:
#                                          Rating
# Genres
# Action                                 4.285475
# Action;Action & Adventure              4.311765
# Adventure                              4.180822
# Adventure;Action & Adventure           4.423077
# Adventure;Brain Games                  4.600000
# Adventure;Education                    4.100000
# Arcade                                 4.304348
# Arcade;Action & Adventure              4.346667
# Arcade;Pretend Play                    4.500000
# Art & Design                           4.358929
# Art & Design;Action & Adventure             NaN
# Art & Design;Creativity                4.400000
# Art & Design;Pretend Play              3.900000
# Auto & Vehicles                        4.190411
# Beauty                                 4.278571
# Board                                  4.292683
# Board;Action & Adventure               4.033333
# Board;Brain Games                      4.340000
# ...

# %%
w=app.Type.value_counts()
w.plot(kind='pie',
                    subplots=True,
                    figsize=(5,5),
                    autopct="%.2f",
                    legend=False )
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CB38CCC7B8>],
#       dtype=object)

# %% [markdown]
# This pie graph Tell that free apps are most popular that the paid apps ,free apps are the generally first choice of playstore users

# %%
app.plot(subplots= True,figsize=(10,10))
plt.show()

# %% [markdown]
# Now i can't conclude anything on this graph

# %%
app.head(25).plot(kind='bar')
plt.title("Rating of top Apps")
plt.xlabel('App')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# This graphs shows that very Few apps have poor rating of less than 3 and most apps are rated good

# %%
app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
x=app.Type.value_counts()
ax =x.plot.bar(title='Types of App Paid or Free',color='g',alpha=1)

# %% [markdown]
# This bar graph concludes more clearly that people prefer free apps than paid

# %%
x=app.Installs.value_counts()
ax =x.plot.bar(title='number of apps having this much installations',color='g',alpha=1)
plt.xlabel('number of installations')
# Out:
# Text(0.5, 0, 'number of installations')

# %% [markdown]
# Very few apps on playstore have 100 Millions + downloads

# %%
app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
col=['Category','Rating','Genres']
# pokemon.groupby('Stage').count()
means=app[col].groupby(by='Genres').mean()
ax=means.head().plot(kind='pie',figsize=(5,5),subplots=True,autopct='%.lf%%')

# %% [markdown]
# This pie graph shows the share of different genres  in top apps .Grpah shows that every genre has almost equal share in popularity

# %%
ay=means.head().plot(kind='bar',figsize=(5,5),alpha=0.5)

# %% [markdown]
# This bar graph concludes that Adventures and Brain games has best rated apps on playstore

# %%
app.plot(style=',')

# %% [markdown]
# Very Bleak obervation that comes is that very less apps on playstore have poor rating less than 2.5

# %%
app[['Rating']].plot.scatter(x='Rating',y='Rating',alpha=0.5)

# %% [markdown]
# This graph is attempt to use scatter function but since no other coloumn is directly plotable so this graph happens

# %%
app.Price.value_counts().plot(kind='pie',figsize=(10,10))

# %% [markdown]
# This pie graph shows the price of various apps on playstore,Most of the apps are free and rest major chunk cost less 2$

# %%
app.Price.value_counts().plot.bar(figsize=(10,10))

# %% [markdown]
# Now this bar graph is again on Price and shows that free apps are the major chunk of total apps on playstore

# %%
x=app.Category.value_counts()
x.plot(kind='line', subplots=True, figsize=(4,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CB7651D128>],
#       dtype=object)

# %% [markdown]
# This Line graph says that Family and productivity category are area of apps on playstore

# %%
x=app.Price.value_counts()
x.plot(kind='line', subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CB5E8F9198>],
#       dtype=object)

# %% [markdown]
# This line shows the same that very fews apps on playstore are costly annd mostly are free

# %%
x=app['Content Rating'].value_counts()
x.plot(kind='pie', subplots=True, figsize=(8,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CB8D2DD080>],
#       dtype=object)

# %% [markdown]
# This Pie graph shows that most of the apps are for everyone and very few apps are of adult type i.e. 18+

# %% [raw]
# Thank You
